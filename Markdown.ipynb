# %% [markdown]
# # Title
# ## Subtitle
# ### And another one
# ```
# # Title
# ## Subtitle
# ### And another one
# ```

# %% [markdown]
# This is a paragraph in markdown
# And to break a line, hit ```<SPA>``` two times and then ```<RET>```
# Learning __Markdown is easy__, *you just need to pratice* a little bit.
# It a is a **very simple language** and _usefull language_
#
# ```
# This is a paragraph in markdown
# And to break a line you just need to hit <RET>
#
# Learning __Markdown is easy__, *you just need to pratice* a little bit.
# It a is a **very simple language** and _usefull language_
# ```

# %% [markdown]
# > Block quotes make easy to insert direct citations in your file.
# > Block quotes can have as many lines as you want.
# > Thet begin with ```>``` simbol at the beging of the line.
#
# ```
# > Block quotes make easy to insert direct citations in your file
# > Block quotes can hava as many lines as you want
# > They begin with ```>``` simbols at the beging of the line
# ```

# %% [markdown]
# # Listing in markdown
#
# ## Unordered lists
# - This is a item of a list
# - This is another item of a list
#
# Write your paragraph here.
#
# * This is also a list
# * *Now we cant mix thing up*
#
# + **This also works**
#     + Subitem of a list
# + Haven't I said that **__Markdown__** is cup of tea ?
#     * Another subitem
#
# ## Ordered lists
# 1. Ordering a list is simple
# 2. And pratical
# 3. You should try yourself
#     1. [x] Create a *new* cell
#     2. [ ] Make it a __Markdown__ cell
#     3. [ ] Try it yourself
# 1. The end
#
#
# ```
# # Listing in markdown
#
# ## Unordered lists
# - This is a item of a list
# - This is another item of a list
#
# Write your paragraph here.
#
# * This is also a list
# * *Now we cant mix thing up*
#
# + **This also works**
#     + Subitem of a list
# + Haven't I said that **__Markdown__** is cup of tea ?
#     * Another subitem
#
# ## Ordered lists
# 1. Ordering a list is simple
# 2. And pratical
# 3. You should try yourself
#     1. Create a *new* cell
#     2. Make it a __Markdown__ cell
#     3. Try it yourself
# 1. The end
#
# ```

# %% [markdown]
# ## Rendering images
#
# ![Beared dragon](https://images-na.ssl-images-amazon.com/images/I/917A6jVtepL._SL1500_.jpg)
#
# To re size you should do this
# <img src = "https://images-na.ssl-images-amazon.com/images/I/917A6jVtepL._SL1500_.jpg" height ="200" width ="200">
#
# [This is a link to the site image](https://www.amazon.com/Carolina-Designer-Dragons-Bearded-Dragon/dp/B075CWG9KS)
# Or also this <https://www.amazon.com/Carolina-Designer-Dragons-Bearded-Dragon/dp/B075CWG9KS>
# ```
# ![Beared dragon](https://images-na.ssl-images-amazon.com/images/I/917A6jVtepL._SL1500_.jpg)
#
# To re size you should do this
# <img src = "https://images-na.ssl-images-amazon.com/images/I/917A6jVtepL._SL1500_.jpg" height ="100" width ="100">
#
# [This is a link to the site image](https://www.amazon.com/Carolina-Designer-Dragons-Bearded-Dragon/dp/B075CWG9KS)
# Or also this <https://www.amazon.com/Carolina-Designer-Dragons-Bearded-Dragon/dp/B075CWG9KS>
# ```

# %% [markdown]
# # More about links
#
# ## Wikipedia links
# 1. [Wikipedia page][1] and some text[^1]
#     1. [First link of page][2][^2]
#     2. [Second link in page][3][^3]
#
# ---
# ### Bibliography
# [^1]: Wikipedia page
# [^2]: CAMC
# [^3]: Simplystatistics
#
# [1]: https://en.wikipedia.org/wiki/Data_science "Wikipedia page"
# [2]: https://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/abstract "CAMC"
# [3]: https://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/ "Simplystatistics"
#
# ```
# # More about links
#
# ## Wikipedia links
# 1. [Wikipedia page][1] and some text[^1]
#     1. [First link of page][2][^2]
#     2. [Second link in page][3][^3]
#
# ---
# ### Bibliography
# [^1]: Wikipedia page
# [^2]: CAMC
# [^3]: Simplystatistics
#
# [1]: https://en.wikipedia.org/wiki/Data_science "Wikipedia page"
# [2]: https://cacm.acm.org/magazines/2013/12/169933-data-science-and-prediction/abstract "CAMC"
# [3]: https://simplystatistics.org/2013/12/12/the-key-word-in-data-science-is-not-data-it-is-science/ "Simplystatistics"
# ```

# %% [markdown]
# ID| path
# --|--
# 0 | home
# 1 | home/Docments
# 2 | home/Downloads
